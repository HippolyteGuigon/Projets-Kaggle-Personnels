# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

from Merging import *
from Plotting import *

# %%
df_train_merged = merging()

df_train_merged
# Out:
#               id        date  store_nbr                      family     sales  \
# 0              0  2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1  2013-01-01          1                   BABY CARE     0.000
# 2              2  2013-01-01          1                      BEAUTY     0.000
# 3              3  2013-01-01          1                   BEVERAGES     0.000
# 4              4  2013-01-01          1                       BOOKS     0.000
# ...          ...         ...        ...                         ...       ...
# 3054343  3000883  2017-08-15          9                     POULTRY   438.133
# 3054344  3000884  2017-08-15          9              PREPARED FOODS   154.553
# 3054345  3000885  2017-08-15          9                     PRODUCE  2419.729
# 3054346  3000886  2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3054347  3000887  2017-08-15          9                     SEAFOOD    16.000
#
# ...

# %%
#On réalise un graphique pour montrer l'évolution des ventes sur une période donnée

frequency = "W"

plotting(frequency)

# %% [markdown]
# On voit qu'il y a une grande croissance entre 2013 et 2018, avec une croissance moyenne de 26,5% par an

# %%
#On regarde ensuite en fonction des produits 

pd.DataFrame(df_train_merged.groupby("family").sales.mean().sort_values(ascending=False)).plot(kind="bar", figsize=(12, 12), title="Average sales by category");
